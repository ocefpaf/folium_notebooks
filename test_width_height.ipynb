# %%
import folium

print(folium.__file__)
print(folium.__version__)
# Out:
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/folium/__init__.py
# 0.2.0.dev

# %%
lon = -122.1889
lat = 46.1991

zoom_start = 13

# %% [markdown]
# # Using same width and height triggers the scroll bar

# %%
width, height = 480, 350

fig = folium.element.Figure(width=width, height=height)

m = folium.Map(location=[lat, lon], tiles="OpenStreetMap",
               width=width, height=height, zoom_start=zoom_start)

fig.add_children(m)
fig
# Out:
# <iframe src="data:text/html;base64,..." width="480" height="350"></iframe>

# %% [markdown]
# # Can figure take relative sizes?

# %%
width, height = '100%', 350

fig = folium.element.Figure(width=width, height=height)

m = folium.Map(location=[lat, lon], tiles="OpenStreetMap",
               width=width, height=height, zoom_start=zoom_start)

fig.add_children(m)
fig
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="350"></iframe>

# %% [markdown]
# # I guess not.  (Well, it does make sense for a single HTML page, but not for iframes.)

# %%
width, height = 480, '100%'

fig = folium.element.Figure(width=width, height=height)

m = folium.Map(location=[lat, lon], tiles="OpenStreetMap",
               width=width, height=height, zoom_start=zoom_start)

fig.add_children(m)
fig
# Out:
# <iframe src="data:text/html;base64,..." width="480" height="100%"></iframe>

# %% [markdown]
# # Not that Figure is interpreting this as 50px.  We should raise something and be explicit on the docs.

# %%
width, height = '50%', '100%'

fig = folium.element.Figure(width=width, height=height)

m = folium.Map(location=[lat, lon], tiles="OpenStreetMap",
               width=width, height=height, zoom_start=zoom_start)

fig.add_children(m)
fig
# Out:
# <iframe src="data:text/html;base64,..." width="50%" height="100%"></iframe>

# %%
width, height = '150%', '100%'

try:
    folium.Map(location=[lat, lon], tiles="OpenStreetMap",
               width=width, height=height, zoom_start=zoom_start)
except ValueError as e:
    print(e)
# Out:
# Cannot parse value 150.0 as '%'

# %%
width, height = '50%', '80p'

try:
    folium.Map(location=[lat, lon], tiles="OpenStreetMap",
               width=width, height=height, zoom_start=zoom_start)
except ValueError as e:
    print(e)
# Out:
# Cannot parse value '80p' as '%'

# %%
width, height = width, height = 480, -350

try:
    folium.Map(location=[lat, lon], tiles="OpenStreetMap",
               width=width, height=height, zoom_start=zoom_start)
except ValueError as e:
    print(e)
# Out:
# Cannot parse value -350.0 as 'px'

# %% [markdown]
# # Maybe we should recommend

# %%
width, height = 480, 350

fig = folium.element.Figure(width=width, height=height)

m = folium.Map(location=[lat, lon], tiles="OpenStreetMap",
               width='100%', height='100%', zoom_start=zoom_start)

fig.add_children(m)
fig
# Out:
# <iframe src="data:text/html;base64,..." width="480" height="350"></iframe>
