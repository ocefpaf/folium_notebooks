# %%
import folium

print(folium.__file__)
print(folium.__version__)
# Out:
# /home/filipe/.virtualenvs/iris/lib/python2.7/site-packages/folium/__init__.py
# 0.2.0.dev

# %%
mapa = folium.Map(location=[45.372, -121.6972], zoom_start=12, tiles='Stamen Terrain')

icon = folium.Icon(color='blue', icon_color='white', icon='cloud',
                   angle=0, prefix='glyphicon')
p0 = folium.Marker([45.3788, -121.6625], popup=folium.Popup('Mt. Hood Meadows'), icon=icon)

icon = folium.Icon(color='green')
p1 = folium.Marker([45.3711, -121.7113], popup=folium.Popup('Timberline Lodge'), icon=icon)

p2 = folium.Marker([45.3700, -121.6823], popup=folium.Popup('simple'))

mapa.add_children(p0)
mapa.add_children(p1)
mapa.add_children(p2)
mapa
# Out:
#             <div style="width:100%;">
#             <div style="position:relative;width:100%;height:0;padding-bottom:60%;">
#             <iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;">
#             </iframe>
#             </div></div>
